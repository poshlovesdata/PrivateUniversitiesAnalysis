# %%
import pandas as pd

# %%
pu = pd.read_csv("private_uni_cleaned.csv")

# %%
pu
# Out:
#      Unnamed: 0                                    University Name  \
# 0             0             Wigwe University, Isiokpo Rivers State
# 1             1                           Skyline University, Kano
# 2             2               American University of Nigeria, Yola
# 3             3                     Pan-Atlantic University, Lagos
# 4             4  Elrazi Medical University Yargaya University, ...
# ..          ...                                                ...
# 124         124                       Al-Qalam University, Katsina
# 125         125                         Sam Maris University, Ondo
# 126         126                       Kwararafa University, Wukari
# 127         127                 Al-Muhibbah Open University, Abuja
# 128         128              Iconic Open University, Sokoto State.
#
#                                                Website  Year Established  \
# 0             https://www.wigweuniversity.edu.ng/fees/              2023
# ...

# %%
pu['University Name'] = pu["University Name"].apply(lambda x: x.split(',')[0])
pu
# Out:
#      Unnamed: 0                               University Name  \
# 0             0                              Wigwe University
# 1             1                            Skyline University
# 2             2                American University of Nigeria
# 3             3                       Pan-Atlantic University
# 4             4  Elrazi Medical University Yargaya University
# ..          ...                                           ...
# 124         124                           Al-Qalam University
# 125         125                          Sam Maris University
# 126         126                          Kwararafa University
# 127         127                   Al-Muhibbah Open University
# 128         128                        Iconic Open University
#
#                                                Website  Year Established  \
# 0             https://www.wigweuniversity.edu.ng/fees/              2023
# ...

# %%
pu_reset = pu.reset_index(drop=True)

pu_reset.to_csv("private_uni_cleaned2.csv")
